# %% [markdown]
# #Mahmood Khalil

# %% [markdown]
# *Note: You are currently reading this using Google Colaboratory which is a cloud-hosted version of Jupyter Notebook. This is a document containing both text cells for documentation and runnable code cells. If you are unfamiliar with Jupyter Notebook, watch this 3-minute introduction before starting this challenge: https://www.youtube.com/watch?v=inN8seMm7UI*
#
# ---
#
# In this challenge, you will predict healthcare costs using a regression algorithm.
#
# You are given a dataset that contains information about different people including their healthcare costs. Use the data to predict healthcare costs based on new data.
#
# The first two cells of this notebook import libraries and the data.
#
# Make sure to convert categorical data to numbers. Use 80% of the data as the `train_dataset` and 20% of the data as the `test_dataset`.
#
# `pop` off the "expenses" column from these datasets to create new datasets called `train_labels` and `test_labels`. Use these labels when training your model.
#
# Create a model and train it with the `train_dataset`. Run the final cell in this notebook to check your model. The final cell will use the unseen `test_dataset` to check how well the model generalizes.
#
# To pass the challenge, `model.evaluate` must return a Mean Absolute Error of under 3500. This means it predicts health care costs correctly within $3500.
#
# The final cell will also predict expenses using the `test_dataset` and graph the results.

# %%
# Import libraries. You may or may not use all of these.
# !pip install -q git+https://github.com/tensorflow/docs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

# %%
# Import data
# !wget https://cdn.freecodecamp.org/project-data/health-costs/insurance.csv
dataset = pd.read_csv('insurance.csv')
dataset.tail()
# Out:
# --2022-03-21 02:57:50--  https://cdn.freecodecamp.org/project-data/health-costs/insurance.csv
# Resolving cdn.freecodecamp.org (cdn.freecodecamp.org)... 104.26.3.33, 172.67.70.149, 104.26.2.33, ...
# Connecting to cdn.freecodecamp.org (cdn.freecodecamp.org)|104.26.3.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50264 (49K) [text/csv]
# Saving to: ‘insurance.csv’
#
# insurance.csv       100%[===================>]  49.09K  --.-KB/s    in 0s
#
# 2022-03-21 02:57:50 (110 MB/s) - ‘insurance.csv’ saved [50264/50264]
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
#get all categorical columns
cat_columns = dataset.select_dtypes(['object']).columns

#convert all categorical columns to numeric
dataset[cat_columns] = dataset[cat_columns].apply(lambda x: pd.factorize(x)[0])

#get X/Y train/test data
train_dataset, test_dataset = train_test_split(dataset, shuffle=True, test_size=0.2)

train_labels = train_dataset.pop('expenses')
test_labels = test_dataset.pop('expenses')

sc = StandardScaler()
train_dataset = sc.fit_transform(train_dataset)
test_dataset = sc.transform(test_dataset)

# %%
#build model
model = Sequential()

model.add(tf.keras.layers.Dense(32, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 32, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 32, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 1))

#compile and fit model
model.compile(optimizer = 'adam',loss = 'mean_absolute_error')
model.fit(train_dataset, train_labels, batch_size = 10, epochs = 100, verbose=2)
# Out:
# Epoch 1/100
# 107/107 - 1s - loss: 13307.9473 - 513ms/epoch - 5ms/step
# Epoch 2/100
# 107/107 - 0s - loss: 13130.4824 - 152ms/epoch - 1ms/step
# Epoch 3/100
# 107/107 - 0s - loss: 11804.1865 - 141ms/epoch - 1ms/step
# Epoch 4/100
# 107/107 - 0s - loss: 8738.1172 - 136ms/epoch - 1ms/step
# Epoch 5/100
# 107/107 - 0s - loss: 6316.4087 - 155ms/epoch - 1ms/step
# Epoch 6/100
# 107/107 - 0s - loss: 5112.8877 - 138ms/epoch - 1ms/step
# Epoch 7/100
# 107/107 - 0s - loss: 4192.1616 - 136ms/epoch - 1ms/step
# Epoch 8/100
# 107/107 - 0s - loss: 3806.4597 - 144ms/epoch - 1ms/step
# Epoch 9/100
# 107/107 - 0s - loss: 3680.8799 - 143ms/epoch - 1ms/step
# Epoch 10/100
# 107/107 - 0s - loss: 3597.7043 - 139ms/epoch - 1ms/step
# Epoch 11/100
# 107/107 - 0s - loss: 3536.0562 - 132ms/epoch - 1ms/step
# Epoch 12/100
# 107/107 - 0s - loss: 3485.6616 - 144ms/epoch - 1ms/step
# Epoch 13/100
# 107/107 - 0s - loss: 3429.2332 - 142ms/epoch - 1ms/step
# Epoch 14/100
# 107/107 - 0s - loss: 3384.0132 - 137ms/epoch - 1ms/step
# Epoch 15/100
# 107/107 - 0s - loss: 3339.6570 - 140ms/epoch - 1ms/step
# Epoch 16/100
# 107/107 - 0s - loss: 3299.5376 - 139ms/epoch - 1ms/step
# Epoch 17/100
# 107/107 - 0s - loss: 3258.1550 - 133ms/epoch - 1ms/step
# Epoch 18/100
# 107/107 - 0s - loss: 3218.6687 - 140ms/epoch - 1ms/step
# Epoch 19/100
# 107/107 - 0s - loss: 3174.5388 - 131ms/epoch - 1ms/step
# Epoch 20/100
# 107/107 - 0s - loss: 3136.2285 - 153ms/epoch - 1ms/step
# Epoch 21/100
# 107/107 - 0s - loss: 3101.5649 - 145ms/epoch - 1ms/step
# Epoch 22/100
# 107/107 - 0s - loss: 3058.0261 - 137ms/epoch - 1ms/step
# Epoch 23/100
# 107/107 - 0s - loss: 3017.5991 - 143ms/epoch - 1ms/step
# Epoch 24/100
# 107/107 - 0s - loss: 2982.7085 - 134ms/epoch - 1ms/step
# Epoch 25/100
# 107/107 - 0s - loss: 2959.3245 - 141ms/epoch - 1ms/step
# Epoch 26/100
# 107/107 - 0s - loss: 2931.7373 - 131ms/epoch - 1ms/step
# Epoch 27/100
# 107/107 - 0s - loss: 2911.6799 - 146ms/epoch - 1ms/step
# Epoch 28/100
# 107/107 - 0s - loss: 2890.7183 - 136ms/epoch - 1ms/step
# Epoch 29/100
# 107/107 - 0s - loss: 2872.4990 - 147ms/epoch - 1ms/step
# Epoch 30/100
# 107/107 - 0s - loss: 2851.0320 - 138ms/epoch - 1ms/step
# Epoch 31/100
# 107/107 - 0s - loss: 2836.6462 - 138ms/epoch - 1ms/step
# Epoch 32/100
# 107/107 - 0s - loss: 2814.1179 - 137ms/epoch - 1ms/step
# Epoch 33/100
# 107/107 - 0s - loss: 2807.6008 - 136ms/epoch - 1ms/step
# Epoch 34/100
# 107/107 - 0s - loss: 2786.3826 - 151ms/epoch - 1ms/step
# Epoch 35/100
# 107/107 - 0s - loss: 2771.0085 - 140ms/epoch - 1ms/step
# Epoch 36/100
# 107/107 - 0s - loss: 2763.5022 - 135ms/epoch - 1ms/step
# Epoch 37/100
# 107/107 - 0s - loss: 2739.1704 - 136ms/epoch - 1ms/step
# Epoch 38/100
# 107/107 - 0s - loss: 2725.9800 - 141ms/epoch - 1ms/step
# Epoch 39/100
# 107/107 - 0s - loss: 2721.4084 - 135ms/epoch - 1ms/step
# Epoch 40/100
# 107/107 - 0s - loss: 2704.0254 - 137ms/epoch - 1ms/step
# Epoch 41/100
# 107/107 - 0s - loss: 2682.4443 - 153ms/epoch - 1ms/step
# Epoch 42/100
# 107/107 - 0s - loss: 2665.5605 - 135ms/epoch - 1ms/step
# Epoch 43/100
# 107/107 - 0s - loss: 2654.8982 - 150ms/epoch - 1ms/step
# Epoch 44/100
# 107/107 - 0s - loss: 2640.9402 - 139ms/epoch - 1ms/step
# Epoch 45/100
# 107/107 - 0s - loss: 2623.7837 - 139ms/epoch - 1ms/step
# Epoch 46/100
# 107/107 - 0s - loss: 2613.3921 - 132ms/epoch - 1ms/step
# Epoch 47/100
# 107/107 - 0s - loss: 2591.5798 - 164ms/epoch - 2ms/step
# Epoch 48/100
# 107/107 - 0s - loss: 2576.6353 - 150ms/epoch - 1ms/step
# Epoch 49/100
# 107/107 - 0s - loss: 2565.0669 - 135ms/epoch - 1ms/step
# Epoch 50/100
# 107/107 - 0s - loss: 2547.9956 - 140ms/epoch - 1ms/step
# Epoch 51/100
# 107/107 - 0s - loss: 2530.4797 - 133ms/epoch - 1ms/step
# Epoch 52/100
# 107/107 - 0s - loss: 2514.3533 - 142ms/epoch - 1ms/step
# Epoch 53/100
# 107/107 - 0s - loss: 2495.5469 - 134ms/epoch - 1ms/step
# Epoch 54/100
# 107/107 - 0s - loss: 2478.5383 - 136ms/epoch - 1ms/step
# Epoch 55/100
# 107/107 - 0s - loss: 2463.3887 - 153ms/epoch - 1ms/step
# Epoch 56/100
# 107/107 - 0s - loss: 2449.7422 - 151ms/epoch - 1ms/step
# Epoch 57/100
# 107/107 - 0s - loss: 2433.0247 - 144ms/epoch - 1ms/step
# Epoch 58/100
# 107/107 - 0s - loss: 2415.0676 - 138ms/epoch - 1ms/step
# Epoch 59/100
# 107/107 - 0s - loss: 2402.9314 - 142ms/epoch - 1ms/step
# Epoch 60/100
# 107/107 - 0s - loss: 2386.8560 - 141ms/epoch - 1ms/step
# Epoch 61/100
# 107/107 - 0s - loss: 2369.2412 - 141ms/epoch - 1ms/step
# Epoch 62/100
# 107/107 - 0s - loss: 2354.3462 - 152ms/epoch - 1ms/step
# Epoch 63/100
# 107/107 - 0s - loss: 2343.5796 - 146ms/epoch - 1ms/step
# Epoch 64/100
# 107/107 - 0s - loss: 2331.0449 - 140ms/epoch - 1ms/step
# Epoch 65/100
# 107/107 - 0s - loss: 2321.6306 - 142ms/epoch - 1ms/step
# Epoch 66/100
# 107/107 - 0s - loss: 2304.7791 - 137ms/epoch - 1ms/step
# Epoch 67/100
# 107/107 - 0s - loss: 2299.6584 - 135ms/epoch - 1ms/step
# Epoch 68/100
# 107/107 - 0s - loss: 2282.7178 - 138ms/epoch - 1ms/step
# Epoch 69/100
# 107/107 - 0s - loss: 2272.7366 - 143ms/epoch - 1ms/step
# Epoch 70/100
# 107/107 - 0s - loss: 2258.3198 - 151ms/epoch - 1ms/step
# Epoch 71/100
# 107/107 - 0s - loss: 2246.3879 - 138ms/epoch - 1ms/step
# Epoch 72/100
# 107/107 - 0s - loss: 2236.7290 - 140ms/epoch - 1ms/step
# Epoch 73/100
# 107/107 - 0s - loss: 2228.2424 - 135ms/epoch - 1ms/step
# Epoch 74/100
# 107/107 - 0s - loss: 2218.1462 - 143ms/epoch - 1ms/step
# Epoch 75/100
# 107/107 - 0s - loss: 2204.2039 - 136ms/epoch - 1ms/step
# Epoch 76/100
# 107/107 - 0s - loss: 2195.0889 - 146ms/epoch - 1ms/step
# Epoch 77/100
# 107/107 - 0s - loss: 2188.8298 - 144ms/epoch - 1ms/step
# Epoch 78/100
# 107/107 - 0s - loss: 2175.1785 - 137ms/epoch - 1ms/step
# Epoch 79/100
# 107/107 - 0s - loss: 2160.4561 - 143ms/epoch - 1ms/step
# Epoch 80/100
# 107/107 - 0s - loss: 2154.2039 - 135ms/epoch - 1ms/step
# Epoch 81/100
# 107/107 - 0s - loss: 2140.4800 - 146ms/epoch - 1ms/step
# Epoch 82/100
# 107/107 - 0s - loss: 2126.8772 - 141ms/epoch - 1ms/step
# Epoch 83/100
# 107/107 - 0s - loss: 2119.2961 - 155ms/epoch - 1ms/step
# Epoch 84/100
# 107/107 - 0s - loss: 2108.9954 - 144ms/epoch - 1ms/step
# Epoch 85/100
# 107/107 - 0s - loss: 2101.8108 - 137ms/epoch - 1ms/step
# Epoch 86/100
# 107/107 - 0s - loss: 2089.4348 - 139ms/epoch - 1ms/step
# Epoch 87/100
# 107/107 - 0s - loss: 2089.0762 - 133ms/epoch - 1ms/step
# Epoch 88/100
# 107/107 - 0s - loss: 2074.7517 - 134ms/epoch - 1ms/step
# Epoch 89/100
# 107/107 - 0s - loss: 2067.8062 - 134ms/epoch - 1ms/step
# Epoch 90/100
# 107/107 - 0s - loss: 2059.4370 - 143ms/epoch - 1ms/step
# Epoch 91/100
# 107/107 - 0s - loss: 2052.0732 - 141ms/epoch - 1ms/step
# Epoch 92/100
# 107/107 - 0s - loss: 2044.6746 - 146ms/epoch - 1ms/step
# Epoch 93/100
# 107/107 - 0s - loss: 2036.4762 - 135ms/epoch - 1ms/step
# Epoch 94/100
# 107/107 - 0s - loss: 2025.6033 - 140ms/epoch - 1ms/step
# Epoch 95/100
# 107/107 - 0s - loss: 2025.9399 - 138ms/epoch - 1ms/step
# Epoch 96/100
# 107/107 - 0s - loss: 2010.6342 - 139ms/epoch - 1ms/step
# Epoch 97/100
# 107/107 - 0s - loss: 2004.5582 - 146ms/epoch - 1ms/step
# Epoch 98/100
# 107/107 - 0s - loss: 2002.4540 - 153ms/epoch - 1ms/step
# Epoch 99/100
# 107/107 - 0s - loss: 1993.0624 - 144ms/epoch - 1ms/step
# Epoch 100/100
# 107/107 - 0s - loss: 1979.9028 - 141ms/epoch - 1ms/step

# %%
# RUN THIS CELL TO TEST YOUR MODEL. DO NOT MODIFY CONTENTS.
# Test model by checking how well the model generalizes using the test set.
mae= model.evaluate(test_dataset, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f} expenses".format(mae))

if mae < 3500:
  print("You passed the challenge. Great job!")
else:
  print("The Mean Abs Error must be less than 3500. Keep trying.")

# Plot predictions.
test_predictions = model.predict(test_dataset).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True values (expenses)')
plt.ylabel('Predictions (expenses)')
lims = [0, 50000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims,lims)
# Out:
# 9/9 - 0s - loss: 1815.6320 - 115ms/epoch - 13ms/step
# Testing set Mean Abs Error: 1815.63 expenses
# You passed the challenge. Great job!
